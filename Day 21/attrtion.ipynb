# %%
import pandas as pd

# %%
df=pd.read_csv("general_data.csv")

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.size
# Out:
# 105840

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 28

# %%
df['NumCompaniesWorked'].value_counts()
# Out:
# 1.0    1558
# 0.0     586
# 3.0     474
# 2.0     438
# 4.0     415
# 7.0     222
# 6.0     208
# 5.0     187
# 9.0     156
# 8.0     147
# Name: NumCompaniesWorked, dtype: int64

# %% [markdown]
# # handling messing value

# %%
df2=df.fillna(method='ffill')

# %%
df2.isna().sum().sum()
# Out:
# 0

# %%
df2.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# # Convert target variable Attrtion to Catergorical format
# ## attrtion is output variable

# %%
df2['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['Department']=le.fit_transform(df['Department'])

# %%
df2.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                   int32
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
df["Attrition"].head(5)
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
df2["Attrition"].head(5)
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['BusinessTravel']=le.fit_transform(df['BusinessTravel'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['Over18']=le.fit_transform(df['Over18'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['Attrition']=le.fit_transform(df['Attrition'])

# %% [markdown]
# # EDA

# %%
df2.describe().T
# Out:
#                           count          mean           std      min  \
# Age                      4410.0     36.923810      9.133301     18.0
# Attrition                4410.0      0.161224      0.367780      0.0
# BusinessTravel           4410.0      1.607483      0.665304      0.0
# Department               4410.0      1.260544      0.527673      0.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0
# Education                4410.0      2.912925      1.023933      1.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0
# EmployeeID               4410.0   2205.500000   1273.201673      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0
# MaritalStatus            4410.0      1.097279      0.729955      0.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0
# NumCompaniesWorked       4410.0      2.693197      2.499167      0.0
# Over18                   4410.0      0.000000      0.000000      0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df2.skew()
# Out:
# Age                        0.413005
# Attrition                  1.843111
# BusinessTravel            -1.438026
# Department                 0.172114
# DistanceFromHome           0.957466
# Education                 -0.289484
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# JobLevel                   1.024703
# MaritalStatus             -0.152071
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.029043
# Over18                     0.000000
# PercentSalaryHike          0.820569
# StandardHours              0.000000
# StockOptionLevel           0.968321
# TotalWorkingYears          1.113861
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
df2.kurt()
# Out:
# Age                       -0.405951
# Attrition                  1.397690
# BusinessTravel             0.698371
# Department                -0.393269
# DistanceFromHome          -0.227045
# Education                 -0.560569
# EmployeeCount              0.000000
# EmployeeID                -1.200000
# JobLevel                   0.395525
# MaritalStatus             -1.115231
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.011277
# Over18                     0.000000
# PercentSalaryHike         -0.302638
# StandardHours              0.000000
# StockOptionLevel           0.361086
# TotalWorkingYears          0.901566
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
df2.hist(figsize=(12,10))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Attrition'}>,
#         <AxesSubplot:title={'center':'BusinessTravel'}>,
#         <AxesSubplot:title={'center':'Department'}>,
#         <AxesSubplot:title={'center':'DistanceFromHome'}>],
#        [<AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'EmployeeCount'}>,
#         <AxesSubplot:title={'center':'EmployeeID'}>,
#         <AxesSubplot:title={'center':'JobLevel'}>,
#         <AxesSubplot:title={'center':'MaritalStatus'}>],
#        [<AxesSubplot:title={'center':'MonthlyIncome'}>,
#         <AxesSubplot:title={'center':'NumCompaniesWorked'}>,
#         <AxesSubplot:title={'center':'Over18'}>,
#         <AxesSubplot:title={'center':'PercentSalaryHike'}>,
#         <AxesSubplot:title={'center':'StandardHours'}>],
#        [<AxesSubplot:title={'center':'StockOptionLevel'}>,
#         <AxesSubplot:title={'center':'TotalWorkingYears'}>,
# ...

# %%
df2.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008649  -0.004729       -0.002590   -0.003455
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# MaritalStatus           -0.095029   0.162070        0.024001   -0.044619
# MonthlyIncome           -0.044314  -0.031176       -0.037597   -0.032237
# NumCompaniesWorked       0.296805   0.041736        0.022088   -0.003179
# ...

# %%
df2.boxplot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df2.Attrition)
plt.plot()
# Out:
# []

# %%
sns.boxplot(df2['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition'>

# %% [markdown]
# # remove useless Feacture

# %%
df2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df2=df2.drop('EmployeeID',axis=1)

# %%
df2=df2.drop("StockOptionLevel",axis=1)

# %%
df2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df2=df2.drop("Gender",axis=1)

# %%
df2.corr()
# very less coorection are DistanceFromHome,EmployeeCount,YearsSinceLastPromotion	,TrainingTimesLastYear
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EmployeeCount                 NaN        NaN             NaN         NaN
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# MaritalStatus           -0.095029   0.162070        0.024001   -0.044619
# MonthlyIncome           -0.044314  -0.031176       -0.037597   -0.032237
# NumCompaniesWorked       0.296805   0.041736        0.022088   -0.003179
# Over18                        NaN        NaN             NaN         NaN
# ...

# %%
# very less coorection are DistanceFromHome,EmployeeCount,YearsSinceLastPromotion	,TrainingTimesLastYear

# %%
df2=df2.drop("DistanceFromHome",axis=1)

# %%
df2=df2.drop("EmployeeCount",axis=1)

# %%
df2=df2.drop("YearsSinceLastPromotion",axis=1)

# %%
df2=df2.drop("TrainingTimesLastYear",axis=1)

# %%
df2=df2.drop("EducationField",axis=1)

# %%
df2=df2.drop("JobRole",axis=1)

# %%
#df2=df2.drop("EducationField",axis=1)

# %%
df2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'Education',
#        'JobLevel', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'TotalWorkingYears',
#        'YearsAtCompany', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # spliting a data sets

# %%
df2.head(2)
# Out:
#    Age  Attrition  BusinessTravel  Department  Education  JobLevel  \
# 0   51          0               2           2          2         1
# 1   31          1               1           1          1         1
#
#    MaritalStatus  MonthlyIncome  NumCompaniesWorked  Over18  \
# 0              1         131160                 1.0       0
# 1              2          41890                 0.0       0
#
#    PercentSalaryHike  StandardHours  TotalWorkingYears  YearsAtCompany  \
# 0                 11              8                1.0               1
# 1                 23              8                6.0               5
#
#    YearsWithCurrManager
# 0                     0
# 1                     4

# %%
x=df2.iloc[:,2:]

# %%
x.head(2)
# Out:
#    BusinessTravel  Department  Education  JobLevel  MaritalStatus  \
# 0               2           2          2         1              1
# 1               1           1          1         1              2
#
#    MonthlyIncome  NumCompaniesWorked  Over18  PercentSalaryHike  \
# 0         131160                 1.0       0                 11
# 1          41890                 0.0       0                 23
#
#    StandardHours  TotalWorkingYears  YearsAtCompany  YearsWithCurrManager
# 0              8                1.0               1                     0
# 1              8                6.0               5                     4

# %%
y=df2.iloc[:,1]

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 4405    0
# 4406    0
# 4407    0
# 4408    0
# 4409    0
# Name: Attrition, Length: 4410, dtype: int32

# %% [markdown]
# # test train split

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3528, 13)

# %%
x_train.head(2)
# Out:
#       BusinessTravel  Department  Education  JobLevel  MaritalStatus  \
# 2048               2           1          3         1              1
# 2728               0           1          2         1              2
#
#       MonthlyIncome  NumCompaniesWorked  Over18  PercentSalaryHike  \
# 2048          22440                 1.0       0                 12
# 2728          86200                 0.0       0                 13
#
#       StandardHours  TotalWorkingYears  YearsAtCompany  YearsWithCurrManager
# 2048              8               11.0              11                    10
# 2728              8               10.0               9                     7

# %%
x_train.columns
# Out:
# Index(['BusinessTravel', 'Department', 'Education', 'JobLevel',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'PercentSalaryHike', 'StandardHours', 'TotalWorkingYears',
#        'YearsAtCompany', 'YearsWithCurrManager'],
#       dtype='object')

# %%
x_test.shape
# Out:
# (882, 13)

# %%
y_train.shape
# Out:
# (3528,)

# %%
y_test.shape
# Out:
# (882,)

# %% [markdown]
# # model bulding using sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # test the model

# %%
y_PRED=lr.predict(x_test)
y_PRED
# Out:
# array([ 0.10463668,  0.10690786,  0.18771694,  0.30580898,  0.01312389,
#         0.2893008 ,  0.11225856,  0.00360539,  0.16202123,  0.20526339,
#        -0.02696403,  0.10401567,  0.04781059,  0.16821197, -0.00962313,
#         0.19007275,  0.01514156,  0.32758439,  0.15904515,  0.17122148,
#         0.04862685,  0.16525497,  0.29671383, -0.01606805,  0.24374188,
#         0.13302878,  0.25015766, -0.09103993,  0.09840763,  0.19967915,
#         0.11598319,  0.08059551,  0.26276567,  0.10580951,  0.19767936,
#         0.04031151,  0.11031826,  0.02676235,  0.05390047,  0.13013666,
#         0.30711438,  0.03453828,  0.03305976,  0.28234247,  0.09167038,
#         0.02611657,  0.25672144,  0.29302413,  0.07456025,  0.10401567,
#        -0.06120262,  0.1574588 ,  0.07649102,  0.1838514 ,  0.14950798,
#         0.18992189,  0.10221934,  0.15618149,  0.23829063, -0.00759842,
#         0.16673094,  0.26396271,  0.00627671,  0.23666149,  0.12943297,
# ...

# %%
#estimate the cost

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
import numpy as np

# %%
RMSE=np.sqrt(mean_squared_error(y_test,y_PRED))

# %%
print(RMSE)
# Out:
# 0.3598108078516677

# %%
R_squ=r2_score(y_test,y_PRED)

# %%
print(R_squ)
# Out:
# 0.05756785922857188
