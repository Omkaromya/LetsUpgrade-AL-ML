# %%
import pandas as pd

# %%
# read csv

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#       ID Gender  Birth Date  Education  JobCategory CurrentSalary  \
# 0      3      f  07/26/1929         12            1    21,450.00
# 1      4      f  04/15/1947          8            1    21,900.00
# 2      8      f  05-06-1966         12            1    21,900.00
# 3      9      f  01/23/1946         15            1    27,900.00
# 4     10      f  02/13/1946         12            1    24,000.00
# ..   ...    ...         ...        ...          ...           ...
# 469  464      m  03/20/1962         19            3    47,550.00
# 470  465      m  07/20/1962         12            1    33,900.00
# 471  470      m  01/22/1964         12            1    26,250.00
# 472  471      m  08-03-1966         15            1    26,400.00
# 473  472      m  02/21/1966         15            1    39,150.00
#
#     After6Months     SalBegin  Job Time  Prev Exep  Minority  Unnamed: 11  \
# 0     16,725.00    12,000.00         98        381         0          NaN
# ...

# %%
datasets=pd.read_excel("datasets.xlsx",sheet_name="DescriptiveStatistics1")

# %%
datasets
# Out:
#       ID Gender           Birth Date  Education  JobCategory  CurrentSalary  \
# 0      3      f           07/26/1929         12            1          21450
# 1      4      f           04/15/1947          8            1          21900
# 2      8      f  1966-06-05 00:00:00         12            1          21900
# 3      9      f           01/23/1946         15            1          27900
# 4     10      f           02/13/1946         12            1          24000
# ..   ...    ...                  ...        ...          ...            ...
# 469  464      m           03/20/1962         19            3          47550
# 470  465      m           07/20/1962         12            1          33900
# 471  470      m           01/22/1964         12            1          26250
# 472  471      m  1966-03-08 00:00:00         15            1          26400
# 473  472      m           02/21/1966         15            1          39150
#
# ...

# %%
#datasets1=pd.read_excel("datasets.xlsx",sheet_name="DescriptiveStatistics2")

# %%
#datasets1

# %% [markdown]
# check whether datasets is null or empty

# %%
datasets.isnull()
# Out:
#         ID  Gender  Birth Date  Education  JobCategory  CurrentSalary  \
# 0    False   False       False      False        False          False
# 1    False   False       False      False        False          False
# 2    False   False       False      False        False          False
# 3    False   False       False      False        False          False
# 4    False   False       False      False        False          False
# ..     ...     ...         ...        ...          ...            ...
# 469  False   False       False      False        False          False
# 470  False   False       False      False        False          False
# 471  False   False       False      False        False          False
# 472  False   False       False      False        False          False
# 473  False   False       False      False        False          False
#
#      After6Months  SalBegin  Job Time  Prev Exep  Minority
# 0           False     False     False      False     False
# ...

# %% [markdown]
# # to check data contain duplicate value

# %%
datasets.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 469    False
# 470    False
# 471    False
# 472    False
# 473    False
# Length: 474, dtype: bool

# %%
# it found use datasets.drop_duplictaed()

# %%
datasets.describe()
# Out:
#                ID   Education  JobCategory  CurrentSalary   After6Months  \
# count  474.000000  474.000000   474.000000     474.000000     474.000000
# mean   237.500000   13.491561     1.411392   34419.567511   25717.827004
# std    136.976275    2.884846     0.773201   17075.661465   12145.928474
# min      1.000000    8.000000     1.000000   15750.000000   12975.000000
# 25%    119.250000   12.000000     1.000000   24000.000000   18468.750000
# 50%    237.500000   12.000000     1.000000   28875.000000   21900.000000
# 75%    355.750000   15.000000     1.000000   36937.500000   27262.500000
# max    474.000000   21.000000     3.000000  135000.000000  107490.000000
#
#            SalBegin    Job Time   Prev Exep    Minority
# count    474.000000  474.000000  474.000000  474.000000
# mean   17016.086498   81.109705   95.860759    0.219409
# std     7870.638154   10.060945  104.586236    0.414284
# min     9000.000000   63.000000    0.000000    0.000000
# ...

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             474 non-null    int64
#  1   Gender         474 non-null    object
#  2   Birth Date     473 non-null    object
#  3   Education      474 non-null    int64
#  4   JobCategory    474 non-null    int64
#  5   CurrentSalary  474 non-null    int64
#  6   After6Months   474 non-null    float64
#  7   SalBegin       474 non-null    int64
#  8   Job Time       474 non-null    int64
#  9   Prev Exep      474 non-null    int64
#  10  Minority       474 non-null    int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 40.9+ KB

# %%
# unary data is used

# %%
data=datasets[['JobCategory','CurrentSalary','After6Months']]

# %%
# to check average salary

# %%
data.mean()
# Out:
# JobCategory          1.411392
# CurrentSalary    34419.567511
# After6Months     25717.827004
# dtype: float64

# %%
# to check median

# %%
data.median()
# Out:
# JobCategory          1.0
# CurrentSalary    28875.0
# After6Months     21900.0
# dtype: float64

# %%
# to check most frequents data

# %%
data.mode()
# Out:
#    JobCategory  CurrentSalary  After6Months
# 0            1          30750       22875.0

# %%
data.std()
# Out:
# JobCategory          0.773201
# CurrentSalary    17075.661465
# After6Months     12145.928474
# dtype: float64

# %%
data.describe()
# Out:
#        JobCategory  CurrentSalary   After6Months
# count   474.000000     474.000000     474.000000
# mean      1.411392   34419.567511   25717.827004
# std       0.773201   17075.661465   12145.928474
# min       1.000000   15750.000000   12975.000000
# 25%       1.000000   24000.000000   18468.750000
# 50%       1.000000   28875.000000   21900.000000
# 75%       1.000000   36937.500000   27262.500000
# max       3.000000  135000.000000  107490.000000

# %%
datasets.describe()
# Out:
#                ID   Education  JobCategory  CurrentSalary   After6Months  \
# count  474.000000  474.000000   474.000000     474.000000     474.000000
# mean   237.500000   13.491561     1.411392   34419.567511   25717.827004
# std    136.976275    2.884846     0.773201   17075.661465   12145.928474
# min      1.000000    8.000000     1.000000   15750.000000   12975.000000
# 25%    119.250000   12.000000     1.000000   24000.000000   18468.750000
# 50%    237.500000   12.000000     1.000000   28875.000000   21900.000000
# 75%    355.750000   15.000000     1.000000   36937.500000   27262.500000
# max    474.000000   21.000000     3.000000  135000.000000  107490.000000
#
#            SalBegin    Job Time   Prev Exep    Minority
# count    474.000000  474.000000  474.000000  474.000000
# mean   17016.086498   81.109705   95.860759    0.219409
# std     7870.638154   10.060945  104.586236    0.414284
# min     9000.000000   63.000000    0.000000    0.000000
# ...

# %%
data.skew()
# Out:
# JobCategory      1.455978
# CurrentSalary    2.124606
# After6Months     2.267649
# dtype: float64

# %%
datasets.skew()
# Out:
# ID               0.000000
# Education       -0.114107
# JobCategory      1.455978
# CurrentSalary    2.124606
# After6Months     2.267649
# SalBegin         2.852856
# Job Time        -0.052570
# Prev Exep        1.509984
# Minority         1.360322
# dtype: float64

# %%
data.kurt()
# Out:
# JobCategory      0.267547
# CurrentSalary    5.377822
# After6Months     6.823250
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(datasets.CurrentSalary)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b57fa78d60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b501affc40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b57fa787c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b501ac16a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b501a8d670>],
#  'means': []}

# %%
plt.hist(datasets.CurrentSalary)
# Out:
# (array([210., 158.,  39.,  28.,  22.,   8.,   4.,   4.,   0.,   1.]),
#  array([ 15750.,  27675.,  39600.,  51525.,  63450.,  75375.,  87300.,
#          99225., 111150., 123075., 135000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(datasets.Education)
# Out:
# (array([ 53.,   0.,   0., 190.,   6., 116.,  70.,   9.,  27.,   3.]),
#  array([ 8. ,  9.3, 10.6, 11.9, 13.2, 14.5, 15.8, 17.1, 18.4, 19.7, 21. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(datasets.Education)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b504d0f550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b504d29e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b504d1e8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b504a9d670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b505265880>],
#  'means': []}
